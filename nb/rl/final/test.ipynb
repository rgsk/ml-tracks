# %%
print('hello')
name = 'rahul'
name
# Out:
# hello
# 'rahul'

# %%
raise AssertionError('some error')
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 raise AssertionError('some error')
#
# AssertionError: some error

# %%
print('mehak')
# Out:
# mehak
